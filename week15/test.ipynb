# %%
import pandas as pd

df=pd.read_csv('dataset/sales_data.csv')

# %%
df.head()
# Out:
#    order_id  product_id       product_name  quantity  price_per_unit  \
# 0      1000         107  Smartphone Tripod         1           69.62
# 1      1001         104     Wireless Mouse         3           59.82
# 2      1002         108     Wireless Mouse         4          107.05
# 3      1003         105          USB-C Hub         4           58.84
# 4      1004         107  Smartphone Tripod         3           63.50
#
#    order_date
# 0  2023-03-16
# 1  2023-01-17
# 2  2023-01-03
# 3  2023-02-20
# 4  2023-01-15

# %%
df[df['product_name']=='Wireless Mouse']
# Out:
#      order_id  product_id    product_name  quantity  price_per_unit  \
# 1        1001         104  Wireless Mouse         3           59.82
# 2        1002         108  Wireless Mouse         4          107.05
# 7        1007         107  Wireless Mouse         4           34.47
# 39       1039         104  Wireless Mouse         1          118.14
# 53       1053         102  Wireless Mouse         4           18.86
# 56       1056         102  Wireless Mouse         2           99.08
# 76       1076         109  Wireless Mouse         3           65.05
# 79       1079         109  Wireless Mouse         4           18.72
# 82       1082         108  Wireless Mouse         4           92.20
# 98       1098         109  Wireless Mouse         1           84.52
# 99       1099         108  Wireless Mouse         4           72.10
# 122      1122         103  Wireless Mouse         2           73.40
# 124      1124         101  Wireless Mouse         1           42.16
# ...

# %%
x=df.groupby('product_name')['price_per_unit'].mean()

print(x)
# Out:
# product_name
# Bluetooth Headphones    70.643095
# External Hard Drive     63.354138
# Gaming Keyboard         68.887895
# LED Desk Lamp           75.874151
# Laptop Stand            61.465472
# Portable Monitor        62.673878
# Smartphone Tripod       68.788511
# USB-C Hub               74.717826
# Webcam                  67.509487
# Wireless Mouse          66.887500
# Name: price_per_unit, dtype: float64
