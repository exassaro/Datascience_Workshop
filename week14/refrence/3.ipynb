# %%
import seaborn
seaborn.__version__

import numpy
numpy.__version__
# Out:
# '2.2.2'

# %% [markdown]
# # histogram

# %%
import seaborn as sns
import numpy as np

# sns.set(style='white')

# generate a random univariate dataset
rs=np.random.RandomState(10)
d=rs.normal(size=100)

# plot a simple histogram and kde
sns.histplot(d,kde=True,color='m')
# KDE (Kernel Density Estimation) curve,  Adds a smooth density curve on top of the histogram.
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # distplot

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot

# generate a random univariate dataset
rs=np.random.RandomState(10)
d=rs.normal(size=100)

# define the color to use 
colors=['r','g','b']

# plot a histogram with multiple colors
sns.histplot(d,bins=10,color=colors[0],alpha=0.3)
sns.kdeplot(d,color=colors[1],linewidth=2)
sns.rugplot(d,color=colors[2])
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # line plot

# %%
import seaborn as sns

fmri=sns.load_dataset('fmri')

# plot the responses for different
# events and regions
sns.lineplot(x='timepoint',
             y='signal',
             hue='region',
             style='event',
             data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# # Lmplot

# %%
import seaborn as sns

df=sns.load_dataset('anscombe')

# show the results of a linear regression
sns.lmplot(x='x',y='y',data=df)

# %% [markdown]
# # stripplot
#
# ### plotting categorical scatter plots with seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

x=['sun','mon','fri','sat','tue','wed','thu']
y=[5,6.7,4,6,2,4.9,1.8]

# plotting strip plot with seaborn
ax=sns.stripplot(x=x,y=y)

ax.set(xlabel='Days',ylabel='Amount_spend')

plt.title('My first graph')

plt.show()

# %% [markdown]
# ### stripplot using inbuilt data-set given in seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

iris=sns.load_dataset('iris')

ax=sns.stripplot(x='species',y='sepal_length',data=iris)

plt.title('graph')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

iris=sns.load_dataset('iris')

ax=sns.stripplot(x='sepal_length',y='species',data=iris)

plt.title('graph')
plt.show()

# %% [markdown]
# # swarmplot

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

iris=sns.load_dataset('iris')
ax=sns.swarmplot(x='species',y='sepal_length',data=iris)

plt.title('graph')
plt.show()

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

iris=sns.load_dataset('iris')
ax=sns.swarmplot(x='sepal_length',y='species',data=iris)

plt.title('graph')
plt.show()

# %% [markdown]
# # barplot

# %%
import seaborn as sns
df=sns.load_dataset('tips')

sns.barplot(x='sex',y='total_bill',data=df,palette='plasma')
# Out:
# C:\Users\hibam\AppData\Local\Temp\ipykernel_3508\3192901149.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='sex',y='total_bill',data=df,palette='plasma')
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# # countplot

# %%
import seaborn as sns

df=sns.load_dataset('tips')
sns.countplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# # boxplot

# %%
import seaborn as sns
df=sns.load_dataset('tips')
sns.boxplot(x='day',y='total_bill',data=df,hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # violinplot

# %%
import seaborn as sns
df=sns.load_dataset('tips')
sns.violinplot(x='day',y='total_bill',data=df,hue='sex',split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # set the background to be white

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips=sns.load_dataset('tips')
sns.set_style('white')

sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# # set the background to ticks

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips=sns.load_dataset('tips')
sns.set_style('ticks')
sns.countplot(x='sex',data=tips,palette='deep')
# Out:
# C:\Users\hibam\AppData\Local\Temp\ipykernel_1188\1388354332.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='deep')
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# # set the background to be darkgrid

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips=sns.load_dataset('tips')
sns.set_style('darkgrid')

sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>
