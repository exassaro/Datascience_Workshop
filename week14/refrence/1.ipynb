# %% [markdown]
# # installation

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\hibam\appdata\local\programs\python\python313\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hibam\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hibam\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hibam\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hibam\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\hibam\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\hibam\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\hibam\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hibam\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hibam\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hibam\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.10.0'

# %% [markdown]
# # visualization

# %%
import matplotlib.pyplot as plt

x=[0,2,4,6,8]
y=[0,4,16,36,64]

fig,ax=plt.subplots()
ax.plot(x,y,marker='o',label='Data points')

ax.set_title('Basic components of matplotlib figure')
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
plt.legend()

plt.show()

# %% [markdown]
# # Line graph

# %%
import matplotlib.pyplot as plt

x=[3,1,3]
y=[3,2,1]

plt.plot(x,y)
plt.title('Line chart')

plt.legend(['Line'])
plt.show()

# %% [markdown]
# # bar chart

# %%
import matplotlib.pyplot as plt

x=[3,1,3,12,2,4,4]
y=[3,2,1,4,5,6,7]

plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.bar(x,y)
plt.title('Bar chart')

plt.legend(['bar'])
plt.show()

# %% [markdown]
# # Histogram

# %%
import matplotlib.pyplot as plt 

x=[1,2,3,4,5,6,7,4]

plt.hist(x,bins=[1,2,3,4,5,6,7])

plt.title('Histogram')
plt.legend(['bar'])

plt.show()

# %%
import matplotlib.pyplot as plt

y=[1,2,5,3,7,8,2]

plt.hist(y,bins=20)
plt.show()

# %% [markdown]
# # scatter plot

# %%
import matplotlib.pyplot as plt

x=[3,1,3,12,2,4,4]
y=[3,2,1,4,5,6,7]

plt.scatter(x,y,alpha=0.5)

plt.legend('A')
plt.title('Scatter chart')
plt.show()

plt.plot(x,y,marker='o')
plt.show()

# %% [markdown]
# # Pie chart

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]

e=(0.1,0,0,0)
plt.pie(x,e)

plt.title('Pie chart')
plt.show()
# Out:
# C:\Users\hibam\AppData\Local\Temp\ipykernel_16400\3773419322.py:6: MatplotlibDeprecationWarning: Passing the explode parameter of pie() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.pie(x,e)

# %% [markdown]
# # stack plot

# %%
import matplotlib.pyplot as plt

days=[1,2,3,4,5]
studying=[7,8,6,11,7]
playing=[8,5,7,8,13]

plt.stackplot(days,studying,playing,colors=['r','c'])
plt.xlabel('Days')

plt.ylabel('No of hours')

plt.title('Representation of study and playing wrt Days')

plt.show()

# %% [markdown]
# # stem plot

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(0.1,2*np.pi,41)
y=np.exp(np.sin(x))

plt.stem(x,y)
plt.show()

# %% [markdown]
# # box plot

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(10)
#Ensures reproducibility → The same random numbers are generated every time you run the code.

data=np.random.normal(100,20,200)

fig=plt.figure(figsize=(10,7))

plt.boxplot(data)
plt.show()

# %% [markdown]
# # error plot

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[1,2,1,2,1,2,1]

y_error=0.2

plt.plot(x,y)

plt.errorbar(x,y,yerr=y_error,fmt='o')
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# # violine plot

# %%
import matplotlib.pyplot as plt
import numpy as np

uniform=np.arange(-100,100)

normal=np.random.normal(size=100)*30

fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2,figsize=(9,4),sharey=True)

ax1.set_title('uniform distribution')
ax1.set_ylabel('observed values')
ax1.violinplot(uniform)

ax2.set_title('normal distribution')
ax2.violinplot(normal)
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x123f94539d0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x123f9453b10>,
#  'cmins': <matplotlib.collections.LineCollection at 0x123f9453c50>,
#  'cbars': <matplotlib.collections.LineCollection at 0x123f9453d90>}
